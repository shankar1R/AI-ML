# %%
# Check aligibility For Driving license
#Data:Licence_data

import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

Data= pd.read_csv("E:\AI&ML\Exel sheets\Licence_data.csv")
Data
# Out:
#     Age  Driving   in Percentage License Aligible/Non Aligible
# 0    11                       50                  Non Aligible
# 1    23                       80                      Aligible
# 2    24                       85                      Aligible
# 3    16                       45                  Non Aligible
# 4    26                       81                      Aligible
# 5    27                       88                      Aligible
# 6    13                       55                  Non Aligible
# 7    21                       89                      Aligible
# 8    18                       90                      Aligible
# 9    19                       85                      Aligible
# 10   15                       43                  Non Aligible
# 11   31                       96                      Aligible
# 12   20                       86                      Aligible
# 13   22                       93                      Aligible
# ...

# %%
plt.scatter(x=Data["Age"],
            y=Data["Performance"],
            c="magenta",
           )
plt.show()

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            19 non-null     int64
#  1   Driving   in Percentage        19 non-null     int64
#  2   License Aligible/Non Aligible  19 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 584.0+ bytes

# %%
Data.describe()
# Out:
#              Age  Driving   in Percentage
# count  19.000000                19.000000
# mean   20.947368                76.789474
# std     6.363731                20.700453
# min    10.000000                42.000000
# 25%    16.500000                55.500000
# 50%    21.000000                85.000000
# 75%    25.500000                91.500000
# max    31.000000               100.000000

# %%
Data.shape
Data.isnull()
# Out:
# (19, 3)

# %%
Data.isnull()
# Out:
#       Age  Driving   in Percentage  License Aligible/Non Aligible
# 0   False                    False                          False
# 1   False                    False                          False
# 2   False                    False                          False
# 3   False                    False                          False
# 4   False                    False                          False
# 5   False                    False                          False
# 6   False                    False                          False
# 7   False                    False                          False
# 8   False                    False                          False
# 9   False                    False                          False
# 10  False                    False                          False
# 11  False                    False                          False
# 12  False                    False                          False
# ...

# %%
# Check aligibility For Driving license
#Data:Licence_data

import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


Data= pd.read_csv("E:\AI&ML\Exel sheets\Licence_data.csv")
Data



x=Data.drop(["License_Status"], axis=1)
y=Data.drop(["Age","Performance"],axis=1)
x
y
# Out:
#    License_Status
# 0       Not issue
# 1          issued
# 2          issued
# 3       Not issue
# 4          issued
# 5          issued
# 6       Not issue
# 7          issued
# 8          issued
# 9          issued
# 10      Not issue
# 11         issued
# 12     Not issued
# 13         issued
# 14      Not issue
# 15         issued
# 16      Not issue
# 17         issued
# 18         issued

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)
# Out:
#     Age  Driving   in Percentage
# 4    26                       81
# 5    27                       88
# 0    11                       50
# 13   22                       93
# 16   17                       56
# 17   30                       98
# 18   30                      100
# 11   31                       96
# 15   25                       97
# 1    23                       80
# 7    21                       89
# 6    13                       55
# 9    19                       85
# 8    18                       90

# %%
# Check aligibility For Driving license
#Data:Licence_data

import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics


Data= pd.read_csv("E:\AI&ML\Exel sheets\Licence_data.csv")

x=Data.drop(["License_Status"], axis=1)
y=Data.drop(["Age","Performance"],axis=1)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(y_train)

model1 = LinearRegression()

model1.fit(x_train,y_train)

y_pridict=model1.predict(x_test)
print(y_pridict)
# Out:
#         License_Status
# 818719  License_Status
# 44667   License_Status
# 772453  License_Status
# 823932  License_Status
# 906966  License_Status
# ...                ...
# 676296  License_Status
# 882809  License_Status
# 649609  License_Status
# 165797  License_Status
# 805035  License_Status
#
# [838860 rows x 1 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2912\1979108533.py in <module>
#      19 model1 = LinearRegression()
#      20
# ---> 21 model1.fit(x_train,y_train)
#      22
#      23 y_pridict=model1.predict(x_test)
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import plotly.express as pl

df= pd.read_csv("E:\AI&ML\Exel sheets\Salary_dataset.csv")
df

df.info()
df.describe()
df.shape
df.isnull()

x=df.drop(["Years_Experience"], axis=1)
y=df.drop(["Salary"],axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Years_Experience  99 non-null     float64
#  1   Salary            99 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import plotly.express as pl

df= pd.read_csv("E:\AI&ML\Exel sheets\Salary_dataset.csv")
df

df.info()
df.describe()
df.shape
df.isnull()

x=df.drop(["Years_Experience"], axis=1)
y=df.drop(["Salary"],axis=1)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Years_Experience  99 non-null     float64
#  1   Salary            99 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB
#     Years_Experience  Salary
# 0              False   False
# 1              False   False
# 2              False   False
# 3              False   False
# 4              False   False
# ..               ...     ...
# 94             False   False
# 95             False   False
# 96             False   False
# 97             False   False
# 98             False   False
#
# [99 rows x 2 columns]

# %%
plt.scatter(x=df["Years_Experience"],
            y=df["Salary"],)

plt.show()

# %%
import pandas as pd 
import numpy as np

data=pd.read_csv("E:\AI&ML\Exel sheets\mlpractise.csv")
data

data.isnull()
# Out:
#          AT      V     AP     RH     PE
# 0     False  False  False  False  False
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 9563  False  False  False  False  False
# 9564  False  False  False  False  False
# 9565  False  False  False  False  False
# 9566  False  False  False  False  False
# 9567  False  False  False  False  False
#
# [9568 rows x 5 columns]

# %% [markdown]
# MULTI LINEAR REGRESSION

# %%
# Combined Cycle Power Plant(DATASET NAME)

# - Temperature (T) in the range 1.81°C and 37.11°C,
# - Ambient Pressure (AP) in the range 992.89-1033.30 milibar,
# - Relative Humidity (RH) in the range 25.56% to 100.16%
# - Exhaust Vacuum (V) in teh range 25.36-81.56 cm Hg
# - Net hourly electrical energy output (EP) 420.26-495.76 MW
# The averages are taken from various sensors located around the plant that record the ambient variables every second. The variables are given without normalization. 


#import librearies
import pandas as pd 
import numpy as np


#import data
data=pd.read_csv("E:\AI&ML\Exel sheets\mlpractise.csv")
print(data.head()) # only print the First 5 lines

data.info() # print the information about data

data.isnull() # find the null values# Define x and y

# Dfine the X and y value
x=data.drop(['PE'],axis=1).values # Drope only electrical value
y=data['PE'].values # print only electrical output
print(x)

print(y)


# split dataset in traing set and testing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)


#training  the  model of training set
ml=LinearRegression() # maodel selecting
print(ml.fit(x_train,y_train))


#pridict the test set result
y_pred=ml.predict(x_test)
print(y_pred)

ml.predict([[14.96,41.76,1024.07,73.17]])

# evaluate the model
from sklearn.metrics import r2_score
score=r2_score=(y_test,y_pred)
score

#visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test,y_pred)
plt.xlabel("Actual value")
plt.ylabel("pridict value")
plt.title("Actual and pridict value")
plt.show()

# pridected values
# d1=pd.DataFrame({"Actual value":y_train,"Pridict value":y_pred,})
print("pridict value:",y_pred)
print("Actual value:",y_train)
# pred_y_df=pd.DataFrame({'Actual value':y_train,'pridict value':y_pred,'Differense':y_pred-y_train})
# d1[0:20]
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB
# [[  14.96   41.76 1024.07   73.17]
#  [  25.18   62.96 1020.04   59.08]
#  [   5.11   39.4  1012.16   92.14]
#  ...
#  [  31.32   74.33 1012.92   36.48]
#  [  24.48   69.45 1013.86   62.39]
#  [  21.6    62.52 1017.23   67.87]]
# [463.26 444.37 488.56 ... 429.57 435.74 453.28]
# LinearRegression()
# ...

# %%
# import matplotlib.pyplot as plt

import pandas as pd 
import numpy as np


#import data
data=pd.read_csv("E:\AI&ML\Exel sheets\mlpractise.csv")
print(data.head()) # only print the First 5 lines

data.info() # print the information about data

data.isnull() # find the null values# Define x and y

# Dfine the X and y value
x=data.drop(['PE'],axis=1).values # Drope only electrical value
y=data['PE'].values # print only electrical output
print(x)

print(y)


# split dataset in traing set and testing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)


#training  the  model of training set
ml=LinearRegression() # maodel selecting
print(ml.fit(x_train,y_train))


#pridict the test set result
y_pred=ml.predict(x_test)
print(y_pred)

ml.predict([[14.96,41.76,1024.07,73.17]])

# evaluate the model
from sklearn.metrics import r2_score
score=r2_score=(y_test,y_pred)
score

import plotly.express as pl
# plt.figure(figsize=(15,10))
fig=pl.scatter(y_test,y_pred)
# plt.xlabel("Actual value")
# plt.ylabel("pridict value")
# plt.title("Actual and pridict value")
# plt.show()
# fig.update_traces()
fig.show("png")
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB
# [[  14.96   41.76 1024.07   73.17]
#  [  25.18   62.96 1020.04   59.08]
#  [   5.11   39.4  1012.16   92.14]
#  ...
#  [  31.32   74.33 1012.92   36.48]
#  [  24.48   69.45 1013.86   62.39]
#  [  21.6    62.52 1017.23   67.87]]
# [463.26 444.37 488.56 ... 429.57 435.74 453.28]
# LinearRegression()
# ...
