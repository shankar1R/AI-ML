# %%
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.linear_model import LinearRegression

Data= pd.read_csv("E:\AI&ML\Exel sheets\Licence_data.csv")
Data
# Out:
#     Age  Driving   in Percentage License Aligible/Non Aligible
# 0    11                       50                  Non Aligible
# 1    23                       80                      Aligible
# 2    24                       85                      Aligible
# 3    16                       45                  Non Aligible
# 4    26                       81                      Aligible
# 5    27                       88                      Aligible
# 6    13                       55                  Non Aligible
# 7    21                       89                      Aligible
# 8    18                       90                      Aligible
# 9    19                       85                      Aligible
# 10   15                       43                  Non Aligible
# 11   31                       96                      Aligible
# 12   20                       86                      Aligible
# 13   22                       93                      Aligible
# ...

# %%
plt.scatter(x=Data["Age"],
            y=Data["Driving   in Percentage"],
            c="magenta",
           )
plt.show()
